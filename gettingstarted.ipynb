# %% [markdown]
# ## MLflow Tracking Server

# %%
import mlflow

# %%
mlflow.set_tracking_uri("http://127.0.0.1:5000")

# %%
mlflow.set_experiment("Check local host connection")

with mlflow.start_run():
    mlflow.log_metric("test",1)
    mlflow.log_metric("Abc",2)
# Out:
# 2025/11/03 12:13:42 INFO mlflow.tracking.fluent: Experiment with name 'Check local host connection' does not exist. Creating a new experiment.
# 🏃 View run intrigued-ant-674 at: http://127.0.0.1:5000/#/experiments/632540149246213870/runs/1e8d556c8204447ead0844471da90e95
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/632540149246213870

# %%
with mlflow.start_run():
    mlflow.log_metric("test1",1)
    mlflow.log_metric("Abc1",2)
# Out:
# 🏃 View run bald-gnat-555 at: http://127.0.0.1:5000/#/experiments/632540149246213870/runs/c14dd6d02d5a40819d11c1de43a628f0
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/632540149246213870

# %%
with mlflow.start_run():
    mlflow.log_metric("test2",1)
    mlflow.log_metric("Abc2",2)
# Out:
# 🏃 View run sincere-croc-929 at: http://127.0.0.1:5000/#/experiments/632540149246213870/runs/396f1f1bea1644b982f858c1bce5b239
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/632540149246213870
