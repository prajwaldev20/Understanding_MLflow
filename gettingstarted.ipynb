# %% [markdown]
# ## MLflow Tracking Server

# %%
import mlflow

# %%
mlflow.set_tracking_uri("http://127.0.0.1:5000")

# %%
mlflow.set_experiment("Check local host connection")

with mlflow.start_run():
    mlflow.log_metric("test",1)
    mlflow.log_metric("Abc",2)
# Out:
# 2025/11/03 17:51:41 INFO mlflow.tracking.fluent: Experiment with name 'Check local host connection' does not exist. Creating a new experiment.
# 🏃 View run blushing-crane-925 at: http://127.0.0.1:5000/#/experiments/329773308831049448/runs/2d18c292b0504de1af841275b96407c0
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/329773308831049448

# %%
with mlflow.start_run():
    mlflow.log_metric("test1",1)
    mlflow.log_metric("Abc1",2)
# Out:
# 🏃 View run omniscient-ant-815 at: http://127.0.0.1:5000/#/experiments/329773308831049448/runs/dc95a025d75a4967b8650e491b462d16
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/329773308831049448

# %%
with mlflow.start_run():
    mlflow.log_metric("test2",1)
    mlflow.log_metric("Abc2",2)
# Out:
# 🏃 View run persistent-doe-456 at: http://127.0.0.1:5000/#/experiments/329773308831049448/runs/66a065a0fecf4e66aebf588b8d82da11
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/329773308831049448
