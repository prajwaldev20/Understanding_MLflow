# %% [markdown]
# ## MLflow Tracking Server

# %%
import mlflow

# %%
mlflow.set_tracking_uri("http://127.0.0.1:5000")

# %%
mlflow.set_experiment("Check local host connection")

with mlflow.start_run():
    mlflow.log_metric("test",1)
    mlflow.log_metric("Abc",2)
# Out:
# 🏃 View run honorable-colt-389 at: http://127.0.0.1:5000/#/experiments/800507497673808857/runs/6ab4ba0f3b49442d9debb087753b194c
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/800507497673808857

# %%
with mlflow.start_run():
    mlflow.log_metric("test1",1)
    mlflow.log_metric("Abc1",2)
# Out:
# 🏃 View run clean-carp-460 at: http://127.0.0.1:5000/#/experiments/800507497673808857/runs/b7b4392b85764ac085dc8a40da76dabb
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/800507497673808857
